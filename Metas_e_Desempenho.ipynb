# %% [markdown]
# <a href="https://colab.research.google.com/github/rennanbp/calculadora-sistore/blob/main/Metas_e_Desempenho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Acompanhamento de Metas e Desempenho**

# %%
import pandas as pd # Uma das principais bibliotecas para analise dados
import numpy as np # utilizada para dados numericos
import random # para atender as necessidade com dados aleatórios
from datetime import datetime, timedelta # transformar dados em frames mais faceis de serem interpretados

# %%
# Lista de produtos, vendedores e regiões

produtos = [
    'Agitador Magnético PC-420D',
    'Centrífuga para Placas e Tubos Axygen',
    'Banho Seco Digital Thermo Fisher',
    'Micropipeta Manual Eppendorf',
    'Espectrofotômetro UV-Vis Agilent',
    'Balança Analítica Ohaus Explorer',
    'Refratômetro Digital Reichert',
    'Termociclador PCR Applied Biosystems',
    'Câmara Climática Binder',
    'Phmetro Digital Hanna Instruments'
]

# Lista de vendedores
vendedores = ['João', 'Maria', 'Carlos', 'Ana', 'Pedro', 'Luísa', 'Fernanda', 'Ricardo']

# Lista de regiões
regioes = ['São Paulo', 'Rio', 'Minas', 'Bahia', 'Paraná', 'Santa Catarina']

# %%
# Agora vamos definir uma função para gerar datas em determinado período
# def é padrão, gerar_datas é um nome dado a ela e (inicio, meses é uma condição)
# return é o retorno da função que abriga o inicio + timedelta que irá aqui nesse caso
# contar 1x a cada 30 dias em range de meses

def gerar_datas(inicio, meses):
    return [inicio + timedelta(days=30*i) for i in range(meses)]

# vamos agregar a função, as variaveis para geração de dados

random.seed(42) # garante dados aleatórios gerados sendo os mesmos sempre que for executado o que garante a reprodução de resultados
datas = gerar_datas(datetime(2024, 3, 1), 10) # esta linha chama a função e agraga a variavel datas
dados = [] # a variavel dados ira armazenar os dados obtidos

# %%
# Ultimo na conclusão desta primeira etapa será o loop para dados aleatórios

for data in datas:
    for vendedor in vendedores:
        produto = random.choice(produtos)
        regiao = random.choice(regioes)
        meta = random.randint(5000, 15000)
        vendas = meta + random.randint(-3000, 5000)
        dados.append([data, vendedor, produto, meta, vendas, regiao])

# %%
df = pd.DataFrame(dados, columns=['Data', 'Vendedor', 'Produto', 'Meta de Vendas',
                                  'Vendas Realizadas', 'Região'])
df.to_csv('base_vendas.csv', index=False)
print(df.head())
# Out:
#         Data Vendedor                                Produto  Meta de Vendas  \
# 0 2024-03-01     João  Centrífuga para Placas e Tubos Axygen            9506
# 1 2024-03-01    Maria           Micropipeta Manual Eppendorf            6679
# 2 2024-03-01   Carlos                Câmara Climática Binder           14674
# 3 2024-03-01      Ana             Agitador Magnético PC-420D            6535
# 4 2024-03-01    Pedro           Micropipeta Manual Eppendorf           14863
#
#    Vendas Realizadas     Região
# 0               8512  São Paulo
# 1               9222        Rio
# 2              15130  São Paulo
# 3               5326  São Paulo
# 4              12080     Paraná

# %%
df
# Out:
#          Data  Vendedor                                Produto  \
# 0  2024-03-01      João  Centrífuga para Placas e Tubos Axygen
# 1  2024-03-01     Maria           Micropipeta Manual Eppendorf
# 2  2024-03-01    Carlos                Câmara Climática Binder
# 3  2024-03-01       Ana             Agitador Magnético PC-420D
# 4  2024-03-01     Pedro           Micropipeta Manual Eppendorf
# ..        ...       ...                                    ...
# 75 2024-11-26       Ana             Agitador Magnético PC-420D
# 76 2024-11-26     Pedro          Refratômetro Digital Reichert
# 77 2024-11-26     Luísa          Refratômetro Digital Reichert
# 78 2024-11-26  Fernanda   Termociclador PCR Applied Biosystems
# 79 2024-11-26   Ricardo           Micropipeta Manual Eppendorf
#
#     Meta de Vendas  Vendas Realizadas          Região
# 0             9506               8512       São Paulo
# 1             6679               9222             Rio
# 2            14674              15130       São Paulo
# 3             6535               5326       São Paulo
# 4            14863              12080          Paraná
# ..             ...                ...             ...
# 75           11209               8226             Rio
# 76           12454              11790           Minas
# 77           14105              16527  Santa Catarina
# 78            8111               7541             Rio
# 79           14489              17516       São Paulo
#
# [80 rows x 6 columns]

# %%
# Retornar o dataframe com visualização completa

pd.set_option("display.max_rows", None, "display.max_columns", None)

display(df)
# Out:
#          Data  Vendedor                                Produto  \
# 0  2024-03-01      João  Centrífuga para Placas e Tubos Axygen
# 1  2024-03-01     Maria           Micropipeta Manual Eppendorf
# 2  2024-03-01    Carlos                Câmara Climática Binder
# 3  2024-03-01       Ana             Agitador Magnético PC-420D
# 4  2024-03-01     Pedro           Micropipeta Manual Eppendorf
# 5  2024-03-01     Luísa                Câmara Climática Binder
# 6  2024-03-01  Fernanda           Micropipeta Manual Eppendorf
# 7  2024-03-01   Ricardo             Agitador Magnético PC-420D
# 8  2024-03-31      João       Espectrofotômetro UV-Vis Agilent
# 9  2024-03-31     Maria       Balança Analítica Ohaus Explorer
# 10 2024-03-31    Carlos  Centrífuga para Placas e Tubos Axygen
# 11 2024-03-31       Ana       Espectrofotômetro UV-Vis Agilent
# 12 2024-03-31     Pedro  Centrífuga para Placas e Tubos Axygen
# 13 2024-03-31     Luísa       Espectrofotômetro UV-Vis Agilent
# 14 2024-03-31  Fernanda           Micropipeta Manual Eppendorf
# 15 2024-03-31   Ricardo           Micropipeta Manual Eppendorf
# 16 2024-04-30      João           Micropipeta Manual Eppendorf
# 17 2024-04-30     Maria   Termociclador PCR Applied Biosystems
# 18 2024-04-30    Carlos       Balança Analítica Ohaus Explorer
# 19 2024-04-30       Ana       Espectrofotômetro UV-Vis Agilent
# 20 2024-04-30     Pedro       Banho Seco Digital Thermo Fisher
# 21 2024-04-30     Luísa   Termociclador PCR Applied Biosystems
# 22 2024-04-30  Fernanda                Câmara Climática Binder
# 23 2024-04-30   Ricardo             Agitador Magnético PC-420D
# 24 2024-05-30      João       Balança Analítica Ohaus Explorer
# 25 2024-05-30     Maria           Micropipeta Manual Eppendorf
# 26 2024-05-30    Carlos   Termociclador PCR Applied Biosystems
# 27 2024-05-30       Ana       Espectrofotômetro UV-Vis Agilent
# 28 2024-05-30     Pedro                Câmara Climática Binder
# 29 2024-05-30     Luísa      Phmetro Digital Hanna Instruments
# 30 2024-05-30  Fernanda       Balança Analítica Ohaus Explorer
# 31 2024-05-30   Ricardo   Termociclador PCR Applied Biosystems
# 32 2024-06-29      João  Centrífuga para Placas e Tubos Axygen
# 33 2024-06-29     Maria          Refratômetro Digital Reichert
# 34 2024-06-29    Carlos          Refratômetro Digital Reichert
# 35 2024-06-29       Ana       Espectrofotômetro UV-Vis Agilent
# 36 2024-06-29     Pedro  Centrífuga para Placas e Tubos Axygen
# 37 2024-06-29     Luísa       Espectrofotômetro UV-Vis Agilent
# 38 2024-06-29  Fernanda       Espectrofotômetro UV-Vis Agilent
# 39 2024-06-29   Ricardo             Agitador Magnético PC-420D
# 40 2024-07-29      João                Câmara Climática Binder
# 29           14560              14831           Bahia
# 30            7266               8440             Rio
# 31            5771               9825       São Paulo
# 32            7621              11109             Rio
# 33            6040               6192          Paraná
# 34           12668              14002          Paraná
# 35            5188               7760          Paraná
# 36           13797              16948  Santa Catarina
# 37           10573               8486  Santa Catarina
# 38            7591               8307           Bahia
# 39            9315              14276  Santa Catarina
# 40           13317              17793             Rio
# 41            9889              13783  Santa Catarina
# 42            8258               6510          Paraná
# 43           13837              18648             Rio
# 44           14813              14468       São Paulo
# 45            6832              11443       São Paulo
# 46            8923               6397           Minas
# 47            6290               3991          Paraná
# 48           13727              17000       São Paulo
# 49           12787              17543             Rio
# 50            9342              10664             Rio
# 51            8470              13079           Bahia
# 52            8295              11135  Santa Catarina
# 53           11118              11706           Bahia
# 54            6982               6012           Bahia
# 55           10539               7711       São Paulo
# 56            8770              10590          Paraná
# 57            6163               8961       São Paulo
# 58            6104              10521             Rio
# 59            6160               7371           Minas
# 60           12953              11708           Minas
# 61           14355              16075             Rio
# 62           12749              16364             Rio
# 63            6545               4339             Rio
# 64           11939              12306           Minas
# 65            5887               8403  Santa Catarina
# 66           11596              14561       São Paulo
# 67            9073               7642       São Paulo
# 68           12350              10498          Paraná
# 69            9563              10352             Rio
# 70           12260              15879       São Paulo
# 71            5828               8170       São Paulo
# 72            6528              11116       São Paulo
# 73           11658              12636             Rio
# 74           11570              15962             Rio
# 75           11209               8226             Rio
# 76           12454              11790           Minas
# 77           14105              16527  Santa Catarina
# 78            8111               7541             Rio
# 79           14489              17516       São Paulo

# %%
marco_meta = df[(df['Data'].dt.month == 3) & (df['Vendas Realizadas'] >= df['Meta de Vendas'])]

print(marco_meta[['Vendedor', 'Vendas Realizadas', 'Meta de Vendas']])
# Out:
#    Vendedor  Vendas Realizadas  Meta de Vendas
# 1     Maria               9222            6679
# 2    Carlos              15130           14674
# 5     Luísa              14364           13928
# 8      João              13368            8527
# 9     Maria               6631            6519
# 10   Carlos              12580           10635
# 11      Ana              13919           12527
# 12    Pedro               7813            6291
# 13    Luísa              12654           10925
# 15  Ricardo              10313            6307

# %%
# Vendedor que mais se destacou entre os meses de Janeiro e Junho
primeiro_semestre = df[(df['Data'].dt.month >= 1) & (df['Data'].dt.month <= 6)]

# Abaixo, a variavel que agrupa por vendedor e soma suas vendas
vendas_por_vendedor = primeiro_semestre.groupby('Vendedor')['Vendas Realizadas'].sum()

# Encontrar vendedor com maior numero de vendas
vendedor_destaque = vendas_por_vendedor.idxmax()

print(f"O vendedor que mais se destacou no primeiro semestre foi: {vendedor_destaque}")
# Out:
# O vendedor que mais se destacou no primeiro semestre foi: Luísa

# %%
# Grupo por região e vendas
vendas_por_regiao = df.groupby('Região')['Vendas Realizadas'].sum()

# Região que mais comprou
regiao_com_mais_compras = vendas_por_regiao.idxmax()

print(f"A região que mais comprou foi: {regiao_com_mais_compras}")
# Out:
# A região que mais comprou foi: Rio

# %%
# Extraia o mês da coluna ‘Dados’ e crie uma nova coluna ‘Mês’
df['Mês'] = df['Data'].dt.month

# Agrupe por mês e some as vendas
vendas_por_mes = df.groupby('Mês')['Vendas Realizadas'].sum()

# Encontre o mês com maiores vendas
mes_com_mais_vendas = vendas_por_mes.idxmax()

print(f"O mês com mais vendas foi: {mes_com_mais_vendas}")
# Out:
# O mês com mais vendas foi: 3
